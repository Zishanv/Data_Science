# %% [markdown]
# # Making Mcdonald's Healthy
#
# ##  A mathematical optimization approach with Python and Pulp

# %% [markdown]
# McDonald’s is known for being unhealthy, but is there a way to create a healthy combination of menu items that meets nutritional guidelines? To answer this question, we can use the power of linear optimization and Python.
#
# First, we need data. A full menu in tabular format with information on calories, macronutrients, and food type is readily available on Kaggle. We also need nutritional guidelines to aim for. A quick Google search leads us to the NHS, which provides recommendations for daily intake of energy, total fat, carbohydrates, sugars, protein, and sodium.
#
# Using linear programming, we can find the optimal combination of McDonald’s menu items that meets these nutritional guidelines. This technique is implemented in the Pulp Python package and allows us to set limitations (nutritional data) and variables (menu items) to achieve our goal.
#
# While McDonald’s is typically viewed as an unhealthy fast food option, by using the power of data analysis and optimization, we can potentially create a healthier menu combination.

# %%
#importing all the necessary libraries needed for this analysis

import numpy as np
import pandas as pd
from pulp import *
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import os

# %%
#loading the data using pandas and looking at the first 5 rows of the data to view the dataset

Mcdata = pd.read_csv('menu.csv')
Mcdata.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 0                             25        0.0  ...             31
# 1                             15        0.0  ...             30
# 2                             42        0.0  ...             29
# 3                             52        0.0  ...             30
# 4                             42        0.0  ...             30
#
#    Carbohydrates (% Daily Value)  Dietary Fiber  \
# 0                             10              4
# 1                             10              4
# 2                             10              4
# 3                             10              4
# 4                             10              4
#
#    Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 0                             17       3       17                         10
# 1                             17       3       18                          6
# 2                             17       2       14                          8
# 3                             17       2       21                         15
# 4                             17       2       21                          6
#
#    Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 0                          0                       25                    15
# 1                          0                       25                     8
# 2                          0                       25                    10
# 3                          0                       30                    15
# 4                          0                       25                    10
#
# [5 rows x 24 columns]

# %%
# The function creates a Scatter graph object (go) and uses the data frame .isin() selection to extract the requested information

def make_scatter(Mcdata,category,x_cat,y_cat):
    return go.Scatter(
        x=Mcdata[Mcdata['Category'].isin([category])][x_cat],
        y=Mcdata[Mcdata['Category'].isin([category])][y_cat],
        mode='markers',
        name=category,
        text=Mcdata.Item)

# %%
# Define our categories to plot
x_cat = 'Calories'; y_cat = 'Carbohydrates'

# Create a list of scatter plots to view all at once
data = [make_scatter(Mcdata,cat,x_cat,y_cat) for cat in Mcdata.Category.unique().tolist()]

# Define the plot layout (title, ticks etc.)
layout = dict(title = 'McDonalds Nutrition',
   xaxis= dict(title= 'Calories',ticklen=5,zeroline= False,range=[0,1250]),
   yaxis= dict(title= 'Carbohydrates(g)',ticklen= 5,zeroline=False))

# Finally we will plot the data with the layout
fig = dict(data = data, layout = layout)
iplot(fig)
# Out:
# <div>                            <div id="ca60d975-f6dc-47ea-bbc3-c783ae070472" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca60d975-f6dc-47ea-bbc3-c783ae070472")) {                    Plotly.newPlot(                        "ca60d975-f6dc-47ea-bbc3-c783ae070472",                        [{"mode":"markers","name":"Breakfast","text":["Egg McMuffin","Egg White Delight","Sausage McMuffin","Sausage McMuffin with Egg","Sausage McMuffin with Egg Whites","Steak & Egg McMuffin","Bacon, Egg & Cheese Biscuit (Regular Biscuit)","Bacon, Egg & Cheese Biscuit (Large Biscuit)","Bacon, Egg & Cheese Biscuit with Egg Whites (Regular Biscuit)","Bacon, Egg & Cheese Biscuit with Egg Whites (Large Biscuit)","Sausage Biscuit (Regular Biscuit)","Sausage Biscuit (Large Biscuit)","Sausage Biscuit with Egg (Regular Biscuit)","Sausage Biscuit with Egg (Large Biscuit)","Sausage Biscuit with Egg Whites (Regular Biscuit)","Sausage Biscuit with Egg Whites (Large Biscuit)","Southern Style Chicken Biscuit (Regular Biscuit)","Southern Style Chicken Biscuit (Large Biscuit)","Steak & Egg Biscuit (Regular Biscuit)","Bacon, Egg & Cheese McGriddles","Bacon, Egg & Cheese McGriddles with Egg Whites","Sausage McGriddles","Sausage, Egg & Cheese McGriddles","Sausage, Egg & Cheese McGriddles with Egg Whites","Bacon, Egg & Cheese Bagel","Bacon, Egg & Cheese Bagel with Egg Whites","Steak, Egg & Cheese Bagel","Big Breakfast (Regular Biscuit)","Big Breakfast (Large Biscuit)","Big Breakfast with Egg Whites (Regular Biscuit)","Big Breakfast with Egg Whites (Large Biscuit)","Big Breakfast with Hotcakes (Regular Biscuit)","Big Breakfast with Hotcakes (Large Biscuit)","Big Breakfast with Hotcakes and Egg Whites (Regular Biscuit)","Big Breakfast with Hotcakes and Egg Whites (Large Biscuit)","Hotcakes","Hotcakes and Sausage","Sausage Burrito","Hash Brown","Cinnamon Melts","Fruit & Maple Oatmeal","Fruit & Maple Oatmeal without Brown Sugar","Big Mac","Quarter Pounder with Cheese","Quarter Pounder with Bacon & Cheese","Quarter Pounder with Bacon Habanero Ranch","Quarter Pounder Deluxe","Double Quarter Pounder with Cheese","Hamburger","Cheeseburger","Double Cheeseburger","Bacon Clubhouse Burger","McDouble","Bacon McDouble","Daily Double","Jalape\u00f1o Double","McRib","Premium Crispy Chicken Classic Sandwich","Premium Grilled Chicken Classic Sandwich","Premium Crispy Chicken Club Sandwich","Premium Grilled Chicken Club Sandwich","Premium Crispy Chicken Ranch BLT Sandwich","Premium Grilled Chicken Ranch BLT Sandwich","Bacon Clubhouse Crispy Chicken Sandwich","Bacon Clubhouse Grilled Chicken Sandwich","Southern Style Crispy Chicken Sandwich","McChicken","Bacon Cheddar McChicken","Bacon Buffalo Ranch McChicken","Buffalo Ranch McChicken","Premium McWrap Chicken & Bacon (Crispy Chicken)","Premium McWrap Chicken & Bacon (Grilled Chicken)","Premium McWrap Chicken & Ranch (Crispy Chicken)","Premium McWrap Chicken & Ranch (Grilled Chicken)","Premium McWrap Southwest Chicken (Crispy Chicken)","Premium McWrap Southwest Chicken (Grilled Chicken)","Premium McWrap Chicken Sweet Chili (Crispy Chicken)","Premium McWrap Chicken Sweet Chili (Grilled Chicken)","Chicken McNuggets (4 piece)","Chicken McNuggets (6 piece)","Chicken McNuggets (10 piece)","Chicken McNuggets (20 piece)","Chicken McNuggets (40 piece)","Filet-O-Fish","Premium Bacon Ranch Salad (without Chicken)","Premium Bacon Ranch Salad with Crispy Chicken","Premium Bacon Ranch Salad with Grilled Chicken","Premium Southwest Salad (without Chicken)","Premium Southwest Salad with Crispy Chicken","Premium Southwest Salad with Grilled Chicken","Chipotle BBQ Snack Wrap (Crispy Chicken)","Chipotle BBQ Snack Wrap (Grilled Chicken)","Honey Mustard Snack Wrap (Crispy Chicken)","Honey Mustard Snack Wrap (Grilled Chicke ...

# %% [markdown]
# ### Let's compare Sodium vs Fat?

# %%
# Define our categories to plot
x_cat = 'Total Fat'; y_cat = 'Sodium'

# Create a list of scatter plots to view all at once
data = [make_scatter(Mcdata,cat,x_cat,y_cat) for cat in Mcdata.Category.unique().tolist()]

# Define the plot layout (title, ticks etc.)
layout = dict(title = 'McDonalds Nutrition',
   xaxis= dict(title= 'Total Far',ticklen=5,zeroline= False,range=[0,65]),
   yaxis= dict(title= 'Sodium',ticklen= 5,zeroline=False))

# Finally we will plot the data with the layout
fig = dict(data = data, layout = layout)
iplot(fig)
# Out:
# <div>                            <div id="682a1c5b-6752-490d-8537-2baeef2981f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("682a1c5b-6752-490d-8537-2baeef2981f4")) {                    Plotly.newPlot(                        "682a1c5b-6752-490d-8537-2baeef2981f4",                        [{"mode":"markers","name":"Breakfast","text":["Egg McMuffin","Egg White Delight","Sausage McMuffin","Sausage McMuffin with Egg","Sausage McMuffin with Egg Whites","Steak & Egg McMuffin","Bacon, Egg & Cheese Biscuit (Regular Biscuit)","Bacon, Egg & Cheese Biscuit (Large Biscuit)","Bacon, Egg & Cheese Biscuit with Egg Whites (Regular Biscuit)","Bacon, Egg & Cheese Biscuit with Egg Whites (Large Biscuit)","Sausage Biscuit (Regular Biscuit)","Sausage Biscuit (Large Biscuit)","Sausage Biscuit with Egg (Regular Biscuit)","Sausage Biscuit with Egg (Large Biscuit)","Sausage Biscuit with Egg Whites (Regular Biscuit)","Sausage Biscuit with Egg Whites (Large Biscuit)","Southern Style Chicken Biscuit (Regular Biscuit)","Southern Style Chicken Biscuit (Large Biscuit)","Steak & Egg Biscuit (Regular Biscuit)","Bacon, Egg & Cheese McGriddles","Bacon, Egg & Cheese McGriddles with Egg Whites","Sausage McGriddles","Sausage, Egg & Cheese McGriddles","Sausage, Egg & Cheese McGriddles with Egg Whites","Bacon, Egg & Cheese Bagel","Bacon, Egg & Cheese Bagel with Egg Whites","Steak, Egg & Cheese Bagel","Big Breakfast (Regular Biscuit)","Big Breakfast (Large Biscuit)","Big Breakfast with Egg Whites (Regular Biscuit)","Big Breakfast with Egg Whites (Large Biscuit)","Big Breakfast with Hotcakes (Regular Biscuit)","Big Breakfast with Hotcakes (Large Biscuit)","Big Breakfast with Hotcakes and Egg Whites (Regular Biscuit)","Big Breakfast with Hotcakes and Egg Whites (Large Biscuit)","Hotcakes","Hotcakes and Sausage","Sausage Burrito","Hash Brown","Cinnamon Melts","Fruit & Maple Oatmeal","Fruit & Maple Oatmeal without Brown Sugar","Big Mac","Quarter Pounder with Cheese","Quarter Pounder with Bacon & Cheese","Quarter Pounder with Bacon Habanero Ranch","Quarter Pounder Deluxe","Double Quarter Pounder with Cheese","Hamburger","Cheeseburger","Double Cheeseburger","Bacon Clubhouse Burger","McDouble","Bacon McDouble","Daily Double","Jalape\u00f1o Double","McRib","Premium Crispy Chicken Classic Sandwich","Premium Grilled Chicken Classic Sandwich","Premium Crispy Chicken Club Sandwich","Premium Grilled Chicken Club Sandwich","Premium Crispy Chicken Ranch BLT Sandwich","Premium Grilled Chicken Ranch BLT Sandwich","Bacon Clubhouse Crispy Chicken Sandwich","Bacon Clubhouse Grilled Chicken Sandwich","Southern Style Crispy Chicken Sandwich","McChicken","Bacon Cheddar McChicken","Bacon Buffalo Ranch McChicken","Buffalo Ranch McChicken","Premium McWrap Chicken & Bacon (Crispy Chicken)","Premium McWrap Chicken & Bacon (Grilled Chicken)","Premium McWrap Chicken & Ranch (Crispy Chicken)","Premium McWrap Chicken & Ranch (Grilled Chicken)","Premium McWrap Southwest Chicken (Crispy Chicken)","Premium McWrap Southwest Chicken (Grilled Chicken)","Premium McWrap Chicken Sweet Chili (Crispy Chicken)","Premium McWrap Chicken Sweet Chili (Grilled Chicken)","Chicken McNuggets (4 piece)","Chicken McNuggets (6 piece)","Chicken McNuggets (10 piece)","Chicken McNuggets (20 piece)","Chicken McNuggets (40 piece)","Filet-O-Fish","Premium Bacon Ranch Salad (without Chicken)","Premium Bacon Ranch Salad with Crispy Chicken","Premium Bacon Ranch Salad with Grilled Chicken","Premium Southwest Salad (without Chicken)","Premium Southwest Salad with Crispy Chicken","Premium Southwest Salad with Grilled Chicken","Chipotle BBQ Snack Wrap (Crispy Chicken)","Chipotle BBQ Snack Wrap (Grilled Chicken)","Honey Mustard Snack Wrap (Crispy Chicken)","Honey Mustard Snack Wrap (Grilled Chicke ...

# %% [markdown]
# We're getting into the fun stuff now - optimizing our meal plan to meet our nutritional goals while minimizing calories.
#
# So, to start, let's define our objective function. Basically, this is what we want to achieve - in this case, we want to minimize calories. After all, who doesn't love tasty food that doesn't pack on the pounds?
#
# But we can't just focus on calories alone. We also want to make sure we're getting all the nutrients we need to keep our bodies happy and healthy. So, we'll need to set some constraints to make sure we're not missing out on anything important.
#
# To do that, we'll use some information from [2] to figure out how much of each nutrient we should be getting each day. Then, we'll convert our data into dictionaries so we can feed it into the optimization function.
#
# It might seem like we're trying to achieve the impossible - getting all the nutrients we need without consuming any calories - but don't worry, we're not expecting miracles here. We just want to get as close as we can to our goals while still enjoying our food. After all, life is too short to eat boring meals!

# %%
# Convert the item names to a list
MenuItems = Mcdata.Item.tolist()


# Convert all of the macro nutrients fields to be dictionaries of the item names
Calories = Mcdata.set_index('Item')['Calories'].to_dict()
TotalFat = Mcdata.set_index('Item')['Total Fat'].to_dict()
SaturatedFat = Mcdata.set_index('Item')['Saturated Fat'].to_dict()
Carbohydrates = Mcdata.set_index('Item')['Carbohydrates'].to_dict()
Sugars = Mcdata.set_index('Item')['Sugars'].to_dict()
Protein = Mcdata.set_index('Item')['Protein'].to_dict()
Sodium = Mcdata.set_index('Item')['Sodium'].to_dict()

# %%
Calories
# Out:
# {'Egg McMuffin': 300,
#  'Egg White Delight': 250,
#  'Sausage McMuffin': 370,
#  'Sausage McMuffin with Egg': 450,
#  'Sausage McMuffin with Egg Whites': 400,
#  'Steak & Egg McMuffin': 430,
#  'Bacon, Egg & Cheese Biscuit (Regular Biscuit)': 460,
#  'Bacon, Egg & Cheese Biscuit (Large Biscuit)': 520,
#  'Bacon, Egg & Cheese Biscuit with Egg Whites (Regular Biscuit)': 410,
#  'Bacon, Egg & Cheese Biscuit with Egg Whites (Large Biscuit)': 470,
#  'Sausage Biscuit (Regular Biscuit)': 430,
#  'Sausage Biscuit (Large Biscuit)': 480,
#  'Sausage Biscuit with Egg (Regular Biscuit)': 510,
#  'Sausage Biscuit with Egg (Large Biscuit)': 570,
#  'Sausage Biscuit with Egg Whites (Regular Biscuit)': 460,
#  'Sausage Biscuit with Egg Whites (Large Biscuit)': 520,
#  'Southern Style Chicken Biscuit (Regular Biscuit)': 410,
#  'Southern Style Chicken Biscuit (Large Biscuit)': 470,
#  'Steak & Egg Biscuit (Regular Biscuit)': 540,
#  'Bacon, Egg & Cheese McGriddles': 460,
#  'Bacon, Egg & Cheese McGriddles with Egg Whites': 400,
#  'Sausage McGriddles': 420,
#  'Sausage, Egg & Cheese McGriddles': 550,
#  'Sausage, Egg & Cheese McGriddles with Egg Whites': 500,
#  'Bacon, Egg & Cheese Bagel': 620,
#  'Bacon, Egg & Cheese Bagel with Egg Whites': 570,
#  'Steak, Egg & Cheese Bagel': 670,
#  'Big Breakfast (Regular Biscuit)': 740,
#  'Big Breakfast (Large Biscuit)': 800,
#  'Big Breakfast with Egg Whites (Regular Biscuit)': 640,
#  'Big Breakfast with Egg Whites (Large Biscuit)': 690,
#  'Big Breakfast with Hotcakes (Regular Biscuit)': 1090,
#  'Big Breakfast with Hotcakes (Large Biscuit)': 1150,
#  'Big Breakfast with Hotcakes and Egg Whites (Regular Biscuit)': 990,
#  'Big Breakfast with Hotcakes and Egg Whites (Large Biscuit)': 1050,
#  'Hotcakes': 350,
#  'Hotcakes and Sausage': 520,
#  'Sausage Burrito': 300,
#  'Hash Brown': 150,
#  'Cinnamon Melts': 460,
#  'Fruit & Maple Oatmeal': 290,
#  'Fruit & Maple Oatmeal without Brown Sugar': 260,
#  'Big Mac': 530,
#  'Quarter Pounder with Cheese': 520,
#  'Quarter Pounder with Bacon & Cheese': 600,
#  'Quarter Pounder with Bacon Habanero Ranch': 610,
#  'Quarter Pounder Deluxe': 540,
#  'Double Quarter Pounder with Cheese': 750,
#  'Hamburger': 240,
#  'Cheeseburger': 290,
#  'Double Cheeseburger': 430,
#  'Bacon Clubhouse Burger': 720,
#  'McDouble': 380,
#  'Bacon McDouble': 440,
#  'Daily Double': 430,
#  'Jalapeño Double': 430,
#  'McRib': 500,
#  'Premium Crispy Chicken Classic Sandwich': 510,
#  'Premium Grilled Chicken Classic Sandwich': 350,
#  'Premium Crispy Chicken Club Sandwich': 670,
#  'Premium Grilled Chicken Club Sandwich': 510,
#  'Premium Crispy Chicken Ranch BLT Sandwich': 610,
#  'Premium Grilled Chicken Ranch BLT Sandwich': 450,
#  'Bacon Clubhouse Crispy Chicken Sandwich': 750,
#  'Bacon Clubhouse Grilled Chicken Sandwich': 590,
#  'Southern Style Crispy Chicken Sandwich': 430,
#  'McChicken': 360,
#  'Bacon Cheddar McChicken': 480,
#  'Bacon Buffalo Ranch McChicken': 430,
#  'Buffalo Ranch McChicken': 360,
#  'Premium McWrap Chicken & Bacon (Crispy Chicken)': 630,
#  'Premium McWrap Chicken & Bacon (Grilled Chicken)': 480,
#  'Premium McWrap Chicken & Ranch (Crispy Chicken)': 610,
#  'Premium McWrap Chicken & Ranch (Grilled Chicken)': 450,
#  'Premium McWrap Southwest Chicken (Crispy Chicken)': 670,
#  'Premium McWrap Southwest Chicken (Grilled Chicken)': 520,
#  'Premium McWrap Chicken Sweet Chili (Crispy Chicken)': 540,
#  'Premium McWrap Chicken Sweet Chili (Grilled Chicken)': 380,
#  'Chicken McNuggets (4 piece)': 190,
#  'Chicken McNuggets (6 piece)': 280,
#  'Chicken McNuggets (10 piece)': 470,
#  'Chicken McNuggets (20 piece)': 940,
#  'Chicken McNuggets (40 piece)': 1880,
#  'Filet-O-Fish': 390,
#  'Premium Bacon Ranch Salad (without Chicken)': 140,
#  'Premium Bacon Ranch Salad with Crispy Chicken': 380,
#  'Premium Bacon Ranch Salad with Grilled Chicken': 220,
#  'Premium Southwest Salad (without Chicken)': 140,
#  'Premium Southwest Salad with Crispy Chicken': 450,
#  'Premium Southwest Salad with Grilled Chicken': 290,
#  'Chipotle BBQ Snack Wrap (Crispy Chicken)': 340,
#  'Chipotle BBQ Snack Wrap (Grilled Chicken)': 260,
#  'Honey Mustard Snack Wrap (Crispy Chicken)': 330,
#  'Honey Mustard Snack Wrap (Grilled Chicken)': 250,
#  'Ranch Snack Wrap (Crispy Chicken)': 360,
#  'Ranch Snack Wrap (Grilled Chicken)': 280,
#  'Small French Fries': 230,
#  'Medium French Fries': 340,
#  'Large French Fries': 510,
#  'Kids French Fries': 110,
#  'Side Salad': 20,
#  'Apple Slices': 15,
#  "Fruit 'n Yogurt Parfait": 150,
#  'Baked Apple Pie': 250,
#  'Chocolate Chip Cookie': 160,
#  'Oatmeal Raisin Cookie': 150,
#  'Kids Ice Cream Cone': 45,
#  'Hot Fudge Sundae': 330,
#  'Hot Caramel Sundae': 340,
#  'Strawberry Sundae': 280,
#  'Coca-Cola Classic (Small)': 140,
#  'Coca-Cola Classic (Medium)': 200,
#  'Coca-Cola Classic (Large)': 280,
#  'Coca-Cola Classic (Child)': 100,
#  'Diet Coke (Small)': 0,
#  'Diet Coke (Medium)': 0,
#  'Diet Coke (Large)': 0,
#  'Diet Coke (Child)': 0,
#  'Dr Pepper (Small)': 140,
#  'Dr Pepper (Medium)': 190,
#  'Dr Pepper (Large)': 270,
#  'Dr Pepper (Child)': 100,
#  'Diet Dr Pepper (Small)': 0,
#  'Diet Dr Pepper (Medium)': 0,
#  'Diet Dr Pepper (Large)': 0,
#  'Diet Dr Pepper (Child)': 0,
#  'Sprite (Small)': 140,
#  'Sprite (Medium)': 200,
#  'Sprite (Large)': 280,
#  'Sprite (Child)': 100,
#  '1% Low Fat Milk Jug': 100,
#  'Fat Free Chocolate Milk Jug': 130,
#  'Minute Maid 100% Apple Juice Box': 80,
#  'Minute Maid Orange Juice (Small)': 150,
#  'Minute Maid Orange Juice (Medium)': 190,
#  'Minute Maid Orange Juice (Large)': 280,
#  'Dasani Water Bottle': 0,
#  'Iced Tea (Small)': 0,
#  'Iced Tea (Medium)': 0,
#  'Iced Tea (Large)': 0,
#  'Iced Tea (Child)': 0,
#  'Sweet Tea (Small)': 150,
#  'Sweet Tea (Medium)': 180,
#  'Sweet Tea (Large)': 220,
#  'Sweet Tea (Child)': 110,
#  'Coffee (Small)': 0,
#  'Coffee (Medium)': 0,
#  'Coffee (Large)': 0,
#  'Latte (Small)': 170,
#  'Latte (Medium)': 210,
#  'Latte (Large)': 280,
#  'Caramel Latte (Small)': 270,
#  'Caramel Latte (Medium)': 340,
#  'Caramel Latte (Large)': 430,
#  'Hazelnut Latte (Small)': 270,
#  'Hazelnut Latte (Medium)': 330,
#  'Hazelnut Latte (Large)': 430,
#  'French Vanilla Latte (Small)': 260,
#  'French Vanilla Latte (Medium)': 330,
#  'French Vanilla Latte (Large)': 420,
#  'Latte with Sugar Free French Vanilla Syrup (Small)': 210,
#  'Latte with Sugar Free French Vanilla Syrup (Medium)': 260,
#  'Latte with Sugar Free French Vanilla Syrup (Large)': 330,
#  'Nonfat Latte (Small)': 100,
#  'Nonfat Latte (Medium)': 130,
#  'Nonfat Latte (Large)': 170,
#  'Nonfat Caramel Latte (Small)': 200,
#  'Nonfat Caramel Latte (Medium)': 250,
#  'Nonfat Caramel Latte (Large)': 310,
#  'Nonfat Hazelnut Latte (Small)': 200,
#  'Nonfat Hazelnut Latte (Medium)': 250,
#  'Nonfat Hazelnut Latte (Large)': 310,
#  'Nonfat French Vanilla Latte (Small)': 190,
#  'Nonfat French Vanilla Latte (Medium)': 240,
#  'Nonfat French Vanilla Latte (Large)': 300,
#  'Nonfat Latte with Sugar Free French Vanilla Syrup (Small)': 140,
#  'Nonfat Latte with Sugar Free French Vanilla Syrup (Medium)': 170,
#  'Nonfat Latte with Sugar Free French Vanilla Syrup (Large)': 220,
#  'Mocha (Small)': 340,
#  'Mocha (Medium)': 410,
#  'Mocha (Large)': 500,
#  'Mocha with Nonfat Milk (Small)': 270,
#  'Mocha with Nonfat Milk (Medium)': 330,
#  'Mocha with Nonfat Milk (Large)': 390,
#  'Caramel Mocha (Small)': 320,
#  'Caramel Mocha (Medium)': 390,
#  'Caramel Mocha (Large)': 480,
#  'Nonfat Caramel Mocha (Small)': 250,
#  'Nonfat Caramel Mocha (Medium)': 310,
#  'Nonfat Caramel Mocha (Large)': 370,
#  'Hot Chocolate (Small)': 360,
#  'Hot Chocolate (Medium)': 440,
#  'Hot Chocolate (Large)': 540,
#  'Hot Chocolate with Nonfat Milk (Small)': 280,
#  'Hot Chocolate with Nonfat Milk (Medium)': 340,
#  'Hot Chocolate with Nonfat Milk (Large)': 400,
#  'Regular Iced Coffee (Small)': 140,
#  'Regular Iced Coffee (Medium)': 190,
#  'Regular Iced Coffee (Large)': 270,
#  'Caramel Iced Coffee (Small)': 130,
#  'Caramel Iced Coffee (Medium)': 180,
#  'Caramel Iced Coffee (Large)': 260,
#  'Hazelnut Iced Coffee (Small)': 130,
#  'Hazelnut Iced Coffee (Medium)': 180,
#  'Hazelnut Iced Coffee (Large)': 250,
#  'French Vanilla Iced Coffee (Small)': 120,
#  'French Vanilla Iced Coffee (Medium)': 170,
#  'French Vanilla Iced Coffee (Large)': 240,
#  'Iced Coffee with Sugar Free French Vanilla Syrup (Small)': 80,
#  'Iced Coffee with Sugar Free French Vanilla Syrup (Medium)': 120,
#  'Iced Coffee with Sugar Free French Vanilla Syrup (Large)': 160,
#  'Iced Mocha (Small)': 290,
#  'Iced Mocha (Medium)': 350,
#  'Iced Mocha (Large)': 480,
#  'Iced Mocha with Nonfat Milk (Small)': 240,
#  'Iced Mocha with Nonfat Milk (Medium)': 290,
#  'Iced Mocha with Nonfat Milk (Large)': 390,
#  'Iced Caramel Mocha (Small)': 280,
#  'Iced Caramel Mocha (Medium)': 340,
#  'Iced Caramel Mocha (Large)': 460,
#  'Iced Nonfat Caramel Mocha (Small)': 230,
#  'Iced Nonfat Caramel Mocha (Medium)': 270,
#  'Iced Nonfat Caramel Mocha (Large)': 370,
#  'Frappé Mocha (Small)': 450,
#  'Frappé Mocha (Medium)': 550,
#  'Frappé Mocha (Large)': 670,
#  'Frappé Caramel (Small)': 450,
#  'Frappé Caramel (Medium)': 550,
#  'Frappé Caramel (Large)': 670,
#  'Frappé Chocolate Chip (Small)': 530,
#  'Frappé Chocolate Chip (Medium)': 630,
#  'Frappé Chocolate Chip (Large)': 760,
#  'Blueberry Pomegranate Smoothie (Small)': 220,
#  'Blueberry Pomegranate Smoothie (Medium)': 260,
#  'Blueberry Pomegranate Smoothie (Large)': 340,
#  'Strawberry Banana Smoothie (Small)': 210,
#  'Strawberry Banana Smoothie (Medium)': 250,
#  'Strawberry Banana Smoothie (Large)': 330,
#  'Mango Pineapple Smoothie (Small)': 210,
#  'Mango Pineapple Smoothie (Medium)': 260,
#  'Mango Pineapple Smoothie (Large)': 340,
#  'Vanilla Shake (Small)': 530,
#  'Vanilla Shake (Medium)': 660,
#  'Vanilla Shake (Large)': 820,
#  'Strawberry Shake (Small)': 550,
#  'Strawberry Shake (Medium)': 690,
#  'Strawberry Shake (Large)': 850,
#  'Chocolate Shake (Small)': 560,
#  'Chocolate Shake (Medium)': 700,
#  'Chocolate Shake (Large)': 850,
#  'Shamrock Shake (Medium)': 660,
#  'Shamrock Shake (Large)': 820,
#  'McFlurry with M&M’s Candies (Small)': 650,
#  'McFlurry with M&M’s Candies (Medium)': 930,
#  'McFlurry with M&M’s Candies (Snack)': 430,
#  'McFlurry with Oreo Cookies (Small)': 510,
#  'McFlurry with Oreo Cookies (Medium)': 690,
#  'McFlurry with Oreo Cookies (Snack)': 340,
#  "McFlurry with Reese's Peanut Butter Cups (Medium)": 810,
#  "McFlurry with Reese's Peanut Butter Cups (Snack)": 410}

# %%
Sugars
# Out:
# {'Egg McMuffin': 3,
#  'Egg White Delight': 3,
#  'Sausage McMuffin': 2,
#  'Sausage McMuffin with Egg': 2,
#  'Sausage McMuffin with Egg Whites': 2,
#  'Steak & Egg McMuffin': 3,
#  'Bacon, Egg & Cheese Biscuit (Regular Biscuit)': 3,
#  'Bacon, Egg & Cheese Biscuit (Large Biscuit)': 4,
#  'Bacon, Egg & Cheese Biscuit with Egg Whites (Regular Biscuit)': 3,
#  'Bacon, Egg & Cheese Biscuit with Egg Whites (Large Biscuit)': 4,
#  'Sausage Biscuit (Regular Biscuit)': 2,
#  'Sausage Biscuit (Large Biscuit)': 3,
#  'Sausage Biscuit with Egg (Regular Biscuit)': 2,
#  'Sausage Biscuit with Egg (Large Biscuit)': 3,
#  'Sausage Biscuit with Egg Whites (Regular Biscuit)': 3,
#  'Sausage Biscuit with Egg Whites (Large Biscuit)': 3,
#  'Southern Style Chicken Biscuit (Regular Biscuit)': 3,
#  'Southern Style Chicken Biscuit (Large Biscuit)': 4,
#  'Steak & Egg Biscuit (Regular Biscuit)': 3,
#  'Bacon, Egg & Cheese McGriddles': 15,
#  'Bacon, Egg & Cheese McGriddles with Egg Whites': 16,
#  'Sausage McGriddles': 15,
#  'Sausage, Egg & Cheese McGriddles': 15,
#  'Sausage, Egg & Cheese McGriddles with Egg Whites': 15,
#  'Bacon, Egg & Cheese Bagel': 7,
#  'Bacon, Egg & Cheese Bagel with Egg Whites': 8,
#  'Steak, Egg & Cheese Bagel': 7,
#  'Big Breakfast (Regular Biscuit)': 3,
#  'Big Breakfast (Large Biscuit)': 3,
#  'Big Breakfast with Egg Whites (Regular Biscuit)': 3,
#  'Big Breakfast with Egg Whites (Large Biscuit)': 4,
#  'Big Breakfast with Hotcakes (Regular Biscuit)': 17,
#  'Big Breakfast with Hotcakes (Large Biscuit)': 17,
#  'Big Breakfast with Hotcakes and Egg Whites (Regular Biscuit)': 17,
#  'Big Breakfast with Hotcakes and Egg Whites (Large Biscuit)': 18,
#  'Hotcakes': 14,
#  'Hotcakes and Sausage': 14,
#  'Sausage Burrito': 2,
#  'Hash Brown': 0,
#  'Cinnamon Melts': 32,
#  'Fruit & Maple Oatmeal': 32,
#  'Fruit & Maple Oatmeal without Brown Sugar': 18,
#  'Big Mac': 9,
#  'Quarter Pounder with Cheese': 10,
#  'Quarter Pounder with Bacon & Cheese': 12,
#  'Quarter Pounder with Bacon Habanero Ranch': 10,
#  'Quarter Pounder Deluxe': 9,
#  'Double Quarter Pounder with Cheese': 10,
#  'Hamburger': 6,
#  'Cheeseburger': 7,
#  'Double Cheeseburger': 7,
#  'Bacon Clubhouse Burger': 14,
#  'McDouble': 7,
#  'Bacon McDouble': 7,
#  'Daily Double': 7,
#  'Jalapeño Double': 6,
#  'McRib': 11,
#  'Premium Crispy Chicken Classic Sandwich': 10,
#  'Premium Grilled Chicken Classic Sandwich': 8,
#  'Premium Crispy Chicken Club Sandwich': 11,
#  'Premium Grilled Chicken Club Sandwich': 9,
#  'Premium Crispy Chicken Ranch BLT Sandwich': 11,
#  'Premium Grilled Chicken Ranch BLT Sandwich': 9,
#  'Bacon Clubhouse Crispy Chicken Sandwich': 16,
#  'Bacon Clubhouse Grilled Chicken Sandwich': 14,
#  'Southern Style Crispy Chicken Sandwich': 7,
#  'McChicken': 5,
#  'Bacon Cheddar McChicken': 6,
#  'Bacon Buffalo Ranch McChicken': 6,
#  'Buffalo Ranch McChicken': 5,
#  'Premium McWrap Chicken & Bacon (Crispy Chicken)': 7,
#  'Premium McWrap Chicken & Bacon (Grilled Chicken)': 6,
#  'Premium McWrap Chicken & Ranch (Crispy Chicken)': 8,
#  'Premium McWrap Chicken & Ranch (Grilled Chicken)': 6,
#  'Premium McWrap Southwest Chicken (Crispy Chicken)': 12,
#  'Premium McWrap Southwest Chicken (Grilled Chicken)': 10,
#  'Premium McWrap Chicken Sweet Chili (Crispy Chicken)': 14,
#  'Premium McWrap Chicken Sweet Chili (Grilled Chicken)': 12,
#  'Chicken McNuggets (4 piece)': 0,
#  'Chicken McNuggets (6 piece)': 0,
#  'Chicken McNuggets (10 piece)': 0,
#  'Chicken McNuggets (20 piece)': 0,
#  'Chicken McNuggets (40 piece)': 1,
#  'Filet-O-Fish': 5,
#  'Premium Bacon Ranch Salad (without Chicken)': 4,
#  'Premium Bacon Ranch Salad with Crispy Chicken': 5,
#  'Premium Bacon Ranch Salad with Grilled Chicken': 4,
#  'Premium Southwest Salad (without Chicken)': 6,
#  'Premium Southwest Salad with Crispy Chicken': 12,
#  'Premium Southwest Salad with Grilled Chicken': 10,
#  'Chipotle BBQ Snack Wrap (Crispy Chicken)': 8,
#  'Chipotle BBQ Snack Wrap (Grilled Chicken)': 7,
#  'Honey Mustard Snack Wrap (Crispy Chicken)': 3,
#  'Honey Mustard Snack Wrap (Grilled Chicken)': 2,
#  'Ranch Snack Wrap (Crispy Chicken)': 3,
#  'Ranch Snack Wrap (Grilled Chicken)': 2,
#  'Small French Fries': 0,
#  'Medium French Fries': 0,
#  'Large French Fries': 0,
#  'Kids French Fries': 0,
#  'Side Salad': 2,
#  'Apple Slices': 3,
#  "Fruit 'n Yogurt Parfait": 23,
#  'Baked Apple Pie': 13,
#  'Chocolate Chip Cookie': 15,
#  'Oatmeal Raisin Cookie': 13,
#  'Kids Ice Cream Cone': 6,
#  'Hot Fudge Sundae': 48,
#  'Hot Caramel Sundae': 43,
#  'Strawberry Sundae': 45,
#  'Coca-Cola Classic (Small)': 39,
#  'Coca-Cola Classic (Medium)': 55,
#  'Coca-Cola Classic (Large)': 76,
#  'Coca-Cola Classic (Child)': 28,
#  'Diet Coke (Small)': 0,
#  'Diet Coke (Medium)': 0,
#  'Diet Coke (Large)': 0,
#  'Diet Coke (Child)': 0,
#  'Dr Pepper (Small)': 35,
#  'Dr Pepper (Medium)': 51,
#  'Dr Pepper (Large)': 70,
#  'Dr Pepper (Child)': 26,
#  'Diet Dr Pepper (Small)': 0,
#  'Diet Dr Pepper (Medium)': 0,
#  'Diet Dr Pepper (Large)': 0,
#  'Diet Dr Pepper (Child)': 0,
#  'Sprite (Small)': 37,
#  'Sprite (Medium)': 54,
#  'Sprite (Large)': 74,
#  'Sprite (Child)': 27,
#  '1% Low Fat Milk Jug': 12,
#  'Fat Free Chocolate Milk Jug': 22,
#  'Minute Maid 100% Apple Juice Box': 19,
#  'Minute Maid Orange Juice (Small)': 30,
#  'Minute Maid Orange Juice (Medium)': 39,
#  'Minute Maid Orange Juice (Large)': 58,
#  'Dasani Water Bottle': 0,
#  'Iced Tea (Small)': 0,
#  'Iced Tea (Medium)': 0,
#  'Iced Tea (Large)': 0,
#  'Iced Tea (Child)': 0,
#  'Sweet Tea (Small)': 36,
#  'Sweet Tea (Medium)': 45,
#  'Sweet Tea (Large)': 54,
#  'Sweet Tea (Child)': 27,
#  'Coffee (Small)': 0,
#  'Coffee (Medium)': 0,
#  'Coffee (Large)': 0,
#  'Latte (Small)': 12,
#  'Latte (Medium)': 15,
#  'Latte (Large)': 20,
#  'Caramel Latte (Small)': 38,
#  'Caramel Latte (Medium)': 48,
#  'Caramel Latte (Large)': 59,
#  'Hazelnut Latte (Small)': 38,
#  'Hazelnut Latte (Medium)': 47,
#  'Hazelnut Latte (Large)': 58,
#  'French Vanilla Latte (Small)': 36,
#  'French Vanilla Latte (Medium)': 45,
#  'French Vanilla Latte (Large)': 56,
#  'Latte with Sugar Free French Vanilla Syrup (Small)': 12,
#  'Latte with Sugar Free French Vanilla Syrup (Medium)': 15,
#  'Latte with Sugar Free French Vanilla Syrup (Large)': 20,
#  'Nonfat Latte (Small)': 13,
#  'Nonfat Latte (Medium)': 16,
#  'Nonfat Latte (Large)': 21,
#  'Nonfat Caramel Latte (Small)': 39,
#  'Nonfat Caramel Latte (Medium)': 48,
#  'Nonfat Caramel Latte (Large)': 59,
#  'Nonfat Hazelnut Latte (Small)': 38,
#  'Nonfat Hazelnut Latte (Medium)': 48,
#  'Nonfat Hazelnut Latte (Large)': 59,
#  'Nonfat French Vanilla Latte (Small)': 37,
#  'Nonfat French Vanilla Latte (Medium)': 46,
#  'Nonfat French Vanilla Latte (Large)': 56,
#  'Nonfat Latte with Sugar Free French Vanilla Syrup (Small)': 13,
#  'Nonfat Latte with Sugar Free French Vanilla Syrup (Medium)': 16,
#  'Nonfat Latte with Sugar Free French Vanilla Syrup (Large)': 21,
#  'Mocha (Small)': 42,
#  'Mocha (Medium)': 53,
#  'Mocha (Large)': 63,
#  'Mocha with Nonfat Milk (Small)': 43,
#  'Mocha with Nonfat Milk (Medium)': 53,
#  'Mocha with Nonfat Milk (Large)': 64,
#  'Caramel Mocha (Small)': 40,
#  'Caramel Mocha (Medium)': 50,
#  'Caramel Mocha (Large)': 60,
#  'Nonfat Caramel Mocha (Small)': 41,
#  'Nonfat Caramel Mocha (Medium)': 51,
#  'Nonfat Caramel Mocha (Large)': 61,
#  'Hot Chocolate (Small)': 45,
#  'Hot Chocolate (Medium)': 56,
#  'Hot Chocolate (Large)': 68,
#  'Hot Chocolate with Nonfat Milk (Small)': 46,
#  'Hot Chocolate with Nonfat Milk (Medium)': 57,
#  'Hot Chocolate with Nonfat Milk (Large)': 69,
#  'Regular Iced Coffee (Small)': 22,
#  'Regular Iced Coffee (Medium)': 30,
#  'Regular Iced Coffee (Large)': 45,
#  'Caramel Iced Coffee (Small)': 21,
#  'Caramel Iced Coffee (Medium)': 28,
#  'Caramel Iced Coffee (Large)': 42,
#  'Hazelnut Iced Coffee (Small)': 20,
#  'Hazelnut Iced Coffee (Medium)': 28,
#  'Hazelnut Iced Coffee (Large)': 41,
#  'French Vanilla Iced Coffee (Small)': 19,
#  'French Vanilla Iced Coffee (Medium)': 26,
#  'French Vanilla Iced Coffee (Large)': 39,
#  'Iced Coffee with Sugar Free French Vanilla Syrup (Small)': 1,
#  'Iced Coffee with Sugar Free French Vanilla Syrup (Medium)': 2,
#  'Iced Coffee with Sugar Free French Vanilla Syrup (Large)': 2,
#  'Iced Mocha (Small)': 34,
#  'Iced Mocha (Medium)': 43,
#  'Iced Mocha (Large)': 62,
#  'Iced Mocha with Nonfat Milk (Small)': 35,
#  'Iced Mocha with Nonfat Milk (Medium)': 43,
#  'Iced Mocha with Nonfat Milk (Large)': 62,
#  'Iced Caramel Mocha (Small)': 33,
#  'Iced Caramel Mocha (Medium)': 41,
#  'Iced Caramel Mocha (Large)': 59,
#  'Iced Nonfat Caramel Mocha (Small)': 33,
#  'Iced Nonfat Caramel Mocha (Medium)': 41,
#  'Iced Nonfat Caramel Mocha (Large)': 59,
#  'Frappé Mocha (Small)': 57,
#  'Frappé Mocha (Medium)': 71,
#  'Frappé Mocha (Large)': 88,
#  'Frappé Caramel (Small)': 57,
#  'Frappé Caramel (Medium)': 71,
#  'Frappé Caramel (Large)': 88,
#  'Frappé Chocolate Chip (Small)': 67,
#  'Frappé Chocolate Chip (Medium)': 81,
#  'Frappé Chocolate Chip (Large)': 99,
#  'Blueberry Pomegranate Smoothie (Small)': 44,
#  'Blueberry Pomegranate Smoothie (Medium)': 54,
#  'Blueberry Pomegranate Smoothie (Large)': 70,
#  'Strawberry Banana Smoothie (Small)': 44,
#  'Strawberry Banana Smoothie (Medium)': 54,
#  'Strawberry Banana Smoothie (Large)': 70,
#  'Mango Pineapple Smoothie (Small)': 46,
#  'Mango Pineapple Smoothie (Medium)': 56,
#  'Mango Pineapple Smoothie (Large)': 72,
#  'Vanilla Shake (Small)': 63,
#  'Vanilla Shake (Medium)': 81,
#  'Vanilla Shake (Large)': 101,
#  'Strawberry Shake (Small)': 79,
#  'Strawberry Shake (Medium)': 100,
#  'Strawberry Shake (Large)': 123,
#  'Chocolate Shake (Small)': 77,
#  'Chocolate Shake (Medium)': 97,
#  'Chocolate Shake (Large)': 120,
#  'Shamrock Shake (Medium)': 93,
#  'Shamrock Shake (Large)': 115,
#  'McFlurry with M&M’s Candies (Small)': 89,
#  'McFlurry with M&M’s Candies (Medium)': 128,
#  'McFlurry with M&M’s Candies (Snack)': 59,
#  'McFlurry with Oreo Cookies (Small)': 64,
#  'McFlurry with Oreo Cookies (Medium)': 85,
#  'McFlurry with Oreo Cookies (Snack)': 43,
#  "McFlurry with Reese's Peanut Butter Cups (Medium)": 103,
#  "McFlurry with Reese's Peanut Butter Cups (Snack)": 51}

# %% [markdown]
# ####  Now that we have all of the data in the correct formats we can go ahead and set up the optimizer!

# %% [markdown]
# ## Setting Up the Optimizer

# %%
# Set it up as a minimization problem
prob = LpProblem('McOptimization Problem', LpMinimize)
# Out:
# /Users/zishanvisram/opt/anaconda3/lib/python3.9/site-packages/pulp/pulp.py:1352: UserWarning:
#
# Spaces are not permitted in the name. Converted to '_'

# %% [markdown]
# In addition, we can tell the optimizer that we are only interested in Integer solutions. ie. we will say it is impossible to have only 0.5 of an item (no half cheeseburgers). On top of this we can choose a max and min number of items for a solution:

# %%
MenuItems_vars = LpVariable.dicts('MenuItems',MenuItems,lowBound=0,
   upBound=10,cat='Integer')

# %%
# First entry is the calorie calculation (this is our objective)
prob += lpSum([Calories[i]*MenuItems_vars[i] for i in MenuItems]),'Calories'
    
# Total Fat must be <= 70 g
prob += lpSum([TotalFat[i]*MenuItems_vars[i] for i in MenuItems]) <= 70, 'TotalFat'
    
# Saturated Fat is <= 20 g
prob += lpSum([SaturatedFat[i]*MenuItems_vars[i] for i in MenuItems]) <= 20, 'Saturated Fat'

# Carbohydrates must be more than 260 g
prob += lpSum([Carbohydrates[i]*MenuItems_vars[i] for i in MenuItems]) >= 260, 'Carbohydrates_lower'

# Sugar between 80-100 g
prob += lpSum([Sugars[i]*MenuItems_vars[i] for i in MenuItems]) >= 80, 'Sugars_lower'
prob += lpSum([Sugars[i]*MenuItems_vars[i] for i in MenuItems]) <= 100, 'Sugars_upper'
    
# Protein between 45-55g
prob += lpSum([Protein[i]*MenuItems_vars[i] for i in MenuItems]) >= 45, 'Protein_lower'
prob += lpSum([Protein[i]*MenuItems_vars[i] for i in MenuItems]) <= 55, 'Protein_upper'
    
# Sodium <= 6000 mg
prob += lpSum([Sodium[i]*MenuItems_vars[i] for i in MenuItems]) <= 6000, 'Sodium'

# %%
prob.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/zishanvisram/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/z3/4grcssw54_sdsl_mwrvm44rw0000gn/T/67a4c219f8474b368e8e35b6ab4a1840-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/z3/4grcssw54_sdsl_mwrvm44rw0000gn/T/67a4c219f8474b368e8e35b6ab4a1840-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 2612 RHS
# At line 2621 BOUNDS
# At line 2878 ENDATA
# Problem MODEL has 8 rows, 256 columns and 1842 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1359.9 - 0.00 seconds
# Cgl0004I processed model has 6 rows, 237 columns (237 integer (97 of which binary)) and 1303 elements
# Cutoff increment increased from 1e-05 to 4.9999
# Cbc0038I Initial state - 3 integers unsatisfied sum - 0.996193
# Cbc0038I Solution found of 1359.9
# Cbc0038I Branch and bound needed to clear up 3 general integers
# Cbc0038I Full problem 6 rows 237 columns, reduced to 6 rows 140 columns
# Cbc0038I Cleaned solution of 1370
# Cbc0038I Before mini branch and bound, 234 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I Round again with cutoff of 1364.49
# Cbc0038I Reduced cost fixing fixed 229 variables on major pass 2
# Cbc0038I Solution found of 1359.9
# Cbc0038I Branch and bound needed to clear up 3 general integers
# Cbc0038I Full problem 7 rows 237 columns, reduced to 5 rows 8 columns
# Cbc0038I Mini branch and bound could not fix general integers
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 234 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of 1370 - took 0.01 seconds
# Cbc0012I Integer solution of 1370 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0038I Full problem 6 rows 237 columns, reduced to 4 rows 5 columns
# Cbc0031I 3 added rows had average density of 4.6666667
# Cbc0013I At root node, 3 cuts changed objective from 1359.8985 to 1362.1592 in 7 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 55 row cuts average 4.5 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1370 best solution, best possible 1362.2074 (0.02 seconds)
# Cbc0001I Search completed - best objective 1370, took 32 iterations and 2 nodes (0.02 seconds)
# Cbc0032I Strong branching done 12 times (16 iterations), fathomed 0 nodes and fixed 2 variables
# Cbc0035I Maximum depth 0, 97 variables fixed on reduced cost
# Cuts at root node changed objective from 1359.9 to 1362.21
# Probing was tried 9 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 7 times and created 55 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1370.00000000
# Enumerated nodes:               2
# Total iterations:               32
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
# 1

# %%
print("Status:", LpStatus[prob.status])
# Out:
# Status: Optimal

# %%
# Get the total calories (minimized)
print("Total Calories = ", value(prob.objective))

# Loop over the constraint set and get the final solution
results = {}
for constraint in prob.constraints:
    s = 0
    for var, coefficient in prob.constraints[constraint].items():
        s += var.varValue * coefficient
    results[prob.constraints[constraint].name.replace('_lower','').replace('_upper','')] = s
# Out:
# Total Calories =  1370.0

# %%
results
# Out:
# {'TotalFat': 20.0,
#  'Saturated_Fat': 7.5,
#  'Carbohydrates': 261.0,
#  'Sugars': 100.0,
#  'Protein': 55.0,
#  'Sodium': 1575.0}

# %%
# Loop over the decision variables and print the items with non-zero quantity
for item in MenuItems_vars:
    if MenuItems_vars[item].value() is not None and MenuItems_vars[item].value() > 0:
        print(item, ":", MenuItems_vars[item].value())
# Out:
# Fruit & Maple Oatmeal without Brown Sugar : 5.0
# Side Salad : 2.0
# Apple Slices : 2.0
# Diet Dr Pepper (Large) : 7.0
